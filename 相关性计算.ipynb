# %%
import mne
import numpy as np

# 读取FIF文件
raw = mne.io.read_raw_fif('E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif', preload=True)  # 替换'your_data.fif'为你的文件路径

# 将EEG数据提取为numpy数组
eeg_data = raw.get_data()
# Out:
# Opening raw data file E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif...
# Isotrak not found
#     Range : 0 ... 30719 =      0.000 ...    29.999 secs
# Ready.
# C:\Users\ANSHANJIAN\AppData\Local\Temp\ipykernel_3160\142293151.py:5: RuntimeWarning: This filename (E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif('E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif', preload=True)  # 替换'your_data.fif'为你的文件路径
# Reading 0 ... 30719  =      0.000 ...    29.999 secs...

# %%
import mne
import numpy as np
import matplotlib.pyplot as plt

# 读取脑电数据文件
raw = mne.io.read_raw_fif('E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif', preload=True)

# 选择所有的脑电通道
channels = raw.ch_names

# 提取所有通道的数据
data, _ = raw[:, :]

# 计算Pearson相关性矩阵
correlation_matrix = np.corrcoef(data)

# 绘制相关性矩阵的热图
plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', aspect='auto', origin='upper')
plt.colorbar()
plt.title('Pearson Correlation Matrix')
plt.xticks(np.arange(len(channels)), channels, rotation=90)
plt.yticks(np.arange(len(channels)), channels)
plt.show()
# Out:
# Opening raw data file E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif...
# Isotrak not found
#     Range : 0 ... 30719 =      0.000 ...    29.999 secs
# Ready.
# Reading 0 ... 30719  =      0.000 ...    29.999 secs...
# C:\Users\ANSHANJIAN\AppData\Local\Temp\ipykernel_3160\346578931.py:6: RuntimeWarning: This filename (E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif('E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif', preload=True)

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import mne

# 1. 读取脑电数据
raw = mne.io.read_raw_fif('E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif', preload=True)

# 2.选择所有的脑电通道
channels = raw.ch_names

# 3. 获取脑电数据
data, times = raw[:, :]

# 4. 计算Spearman相关系数矩阵
spearman_corr_matrix, _ = scipy.stats.spearmanr(data, axis=1)


# 5. 绘制相关性矩阵
plt.figure(figsize=(8, 8))
plt.imshow(spearman_corr_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.title('Spearman Correlation Matrix')
plt.xticks(np.arange(len(channels)), channels, rotation=90)
plt.yticks(np.arange(len(channels)), channels)
plt.show()
# Out:
# Opening raw data file E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif...
# Isotrak not found
#     Range : 0 ... 30719 =      0.000 ...    29.999 secs
# Ready.
# Reading 0 ... 30719  =      0.000 ...    29.999 secs...
# C:\Users\ANSHANJIAN\AppData\Local\Temp\ipykernel_3160\3630916022.py:7: RuntimeWarning: This filename (E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif('E:/学习资料/papers/数据/人民医院 患者脑电数据/脑电切片/SE切片/平均参考/第一批次/EAV-王纯钢-20220321.fif', preload=True)
